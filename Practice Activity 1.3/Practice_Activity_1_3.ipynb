# %% [markdown]
# # Data Visualization Using `plotnine`
#
# The Palmer Penguins dataset had a variety of column types with which to explore some nice visualizations. The `mtcars` dataset is another popular dataset for doing some simple data work, but does not contain the same types of variables.
#
# Run the following code to load the `mtcars` dataset and explore the observations and variables contained within. To learn more about this dataset check out [this site](https://stat.ethz.ch/R-manual/R-devel/library/datasets/html/mtcars.html)

# %%
import statsmodels.api as sm
import pandas as pd

mtcars = sm.datasets.get_rdataset("mtcars", "datasets", cache=True).data
df = pd.DataFrame(mtcars)

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat  ...   qsec  vs  am  gear  carb
# rownames                                          ...
# Mazda RX4            21.0    6  160.0  110  3.90  ...  16.46   0   1     4     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  ...  17.02   0   1     4     4
# Datsun 710           22.8    4  108.0   93  3.85  ...  18.61   1   1     4     1
# Hornet 4 Drive       21.4    6  258.0  110  3.08  ...  19.44   1   0     3     1
# Hornet Sportabout    18.7    8  360.0  175  3.15  ...  17.02   0   0     3     2
# Valiant              18.1    6  225.0  105  2.76  ...  20.22   1   0     3     1
# Duster 360           14.3    8  360.0  245  3.21  ...  15.84   0   0     3     4
# Merc 240D            24.4    4  146.7   62  3.69  ...  20.00   1   0     4     2
# Merc 230             22.8    4  140.8   95  3.92  ...  22.90   1   0     4     2
# Merc 280             19.2    6  167.6  123  3.92  ...  18.30   1   0     4     4
# Merc 280C            17.8    6  167.6  123  3.92  ...  18.90   1   0     4     4
# Merc 450SE           16.4    8  275.8  180  3.07  ...  17.40   0   0     3     3
# Merc 450SL           17.3    8  275.8  180  3.07  ...  17.60   0   0     3     3
# Merc 450SLC          15.2    8  275.8  180  3.07  ...  18.00   0   0     3     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  ...  17.98   0   0     3     4
# Lincoln Continental  10.4    8  460.0  215  3.00  ...  17.82   0   0     3     4
# Chrysler Imperial    14.7    8  440.0  230  3.23  ...  17.42   0   0     3     4
# Fiat 128             32.4    4   78.7   66  4.08  ...  19.47   1   1     4     1
# Honda Civic          30.4    4   75.7   52  4.93  ...  18.52   1   1     4     2
# Toyota Corolla       33.9    4   71.1   65  4.22  ...  19.90   1   1     4     1
# Toyota Corona        21.5    4  120.1   97  3.70  ...  20.01   1   0     3     1
# Dodge Challenger     15.5    8  318.0  150  2.76  ...  16.87   0   0     3     2
# AMC Javelin          15.2    8  304.0  150  3.15  ...  17.30   0   0     3     2
# Camaro Z28           13.3    8  350.0  245  3.73  ...  15.41   0   0     3     4
# Pontiac Firebird     19.2    8  400.0  175  3.08  ...  17.05   0   0     3     2
# Fiat X1-9            27.3    4   79.0   66  4.08  ...  18.90   1   1     4     1
# Porsche 914-2        26.0    4  120.3   91  4.43  ...  16.70   0   1     5     2
# Lotus Europa         30.4    4   95.1  113  3.77  ...  16.90   1   1     5     2
# Ford Pantera L       15.8    8  351.0  264  4.22  ...  14.50   0   1     5     4
# Ferrari Dino         19.7    6  145.0  175  3.62  ...  15.50   0   1     5     6
# Maserati Bora        15.0    8  301.0  335  3.54  ...  14.60   0   1     5     8
# Volvo 142E           21.4    4  121.0  109  4.11  ...  18.60   1   1     4     2
#
# [32 rows x 11 columns]

# %% [markdown]
# The statement "the `mtcars` dataset does not contain the same types of variables as the penguins dataset" is a little true and a little false. There are no variables that contain text values, BUT there are variables that it makes sense to consider categorical variables. In most situations, it makes sense to treat the values of categorical variables as text values instead of numeric values.
#
# Use the `astype()` method to convert the categorical variables of the `mtcars` (df) dataset to have text values in the code chunk below. We've done one for you!

# %%
df["am"] = df["am"].astype(str)

# Convert the other variables below
df["cyl"] = df["cyl"].astype(str)
df["vs"] = df["vs"].astype(str)
df["am"] = df["am"].astype(str)
df["gear"] = df["gear"].astype(str)
df["carb"] = df["carb"].astype(str)
print(df)
# Out:
#                       mpg  cyl   disp   hp  drat  ...   qsec  vs   am gear carb
# rownames                                          ...
# Mazda RX4            21.0  6.0  160.0  110  3.90  ...  16.46   0  1.0    4    4
# Mazda RX4 Wag        21.0  6.0  160.0  110  3.90  ...  17.02   0  1.0    4    4
# Datsun 710           22.8  4.0  108.0   93  3.85  ...  18.61   1  1.0    4    1
# Hornet 4 Drive       21.4  6.0  258.0  110  3.08  ...  19.44   1  0.0    3    1
# Hornet Sportabout    18.7  8.0  360.0  175  3.15  ...  17.02   0  0.0    3    2
# Valiant              18.1  6.0  225.0  105  2.76  ...  20.22   1  0.0    3    1
# Duster 360           14.3  8.0  360.0  245  3.21  ...  15.84   0  0.0    3    4
# Merc 240D            24.4  4.0  146.7   62  3.69  ...  20.00   1  0.0    4    2
# Merc 230             22.8  4.0  140.8   95  3.92  ...  22.90   1  0.0    4    2
# Merc 280             19.2  6.0  167.6  123  3.92  ...  18.30   1  0.0    4    4
# Merc 280C            17.8  6.0  167.6  123  3.92  ...  18.90   1  0.0    4    4
# Merc 450SE           16.4  8.0  275.8  180  3.07  ...  17.40   0  0.0    3    3
# Merc 450SL           17.3  8.0  275.8  180  3.07  ...  17.60   0  0.0    3    3
# Merc 450SLC          15.2  8.0  275.8  180  3.07  ...  18.00   0  0.0    3    3
# Cadillac Fleetwood   10.4  8.0  472.0  205  2.93  ...  17.98   0  0.0    3    4
# Lincoln Continental  10.4  8.0  460.0  215  3.00  ...  17.82   0  0.0    3    4
# Chrysler Imperial    14.7  8.0  440.0  230  3.23  ...  17.42   0  0.0    3    4
# Fiat 128             32.4  4.0   78.7   66  4.08  ...  19.47   1  1.0    4    1
# Honda Civic          30.4  4.0   75.7   52  4.93  ...  18.52   1  1.0    4    2
# Toyota Corolla       33.9  4.0   71.1   65  4.22  ...  19.90   1  1.0    4    1
# Toyota Corona        21.5  4.0  120.1   97  3.70  ...  20.01   1  0.0    3    1
# Dodge Challenger     15.5  8.0  318.0  150  2.76  ...  16.87   0  0.0    3    2
# AMC Javelin          15.2  8.0  304.0  150  3.15  ...  17.30   0  0.0    3    2
# Camaro Z28           13.3  8.0  350.0  245  3.73  ...  15.41   0  0.0    3    4
# Pontiac Firebird     19.2  8.0  400.0  175  3.08  ...  17.05   0  0.0    3    2
# Fiat X1-9            27.3  4.0   79.0   66  4.08  ...  18.90   1  1.0    4    1
# Porsche 914-2        26.0  4.0  120.3   91  4.43  ...  16.70   0  1.0    5    2
# Lotus Europa         30.4  4.0   95.1  113  3.77  ...  16.90   1  1.0    5    2
# Ford Pantera L       15.8  8.0  351.0  264  4.22  ...  14.50   0  1.0    5    4
# Ferrari Dino         19.7  6.0  145.0  175  3.62  ...  15.50   0  1.0    5    6
# Maserati Bora        15.0  8.0  301.0  335  3.54  ...  14.60   0  1.0    5    8
# Volvo 142E           21.4  4.0  121.0  109  4.11  ...  18.60   1  1.0    4    2
#
# [32 rows x 11 columns]
#                       mpg  cyl   disp   hp  drat  ...   qsec  vs   am gear carb
# rownames                                          ...
# Mazda RX4            21.0  6.0  160.0  110  3.90  ...  16.46   0  1.0    4    4
# Mazda RX4 Wag        21.0  6.0  160.0  110  3.90  ...  17.02   0  1.0    4    4
# Datsun 710           22.8  4.0  108.0   93  3.85  ...  18.61   1  1.0    4    1
# Hornet 4 Drive       21.4  6.0  258.0  110  3.08  ...  19.44   1  0.0    3    1
# Hornet Sportabout    18.7  8.0  360.0  175  3.15  ...  17.02   0  0.0    3    2
# Valiant              18.1  6.0  225.0  105  2.76  ...  20.22   1  0.0    3    1
# Duster 360           14.3  8.0  360.0  245  3.21  ...  15.84   0  0.0    3    4
# Merc 240D            24.4  4.0  146.7   62  3.69  ...  20.00   1  0.0    4    2
# Merc 230             22.8  4.0  140.8   95  3.92  ...  22.90   1  0.0    4    2
# Merc 280             19.2  6.0  167.6  123  3.92  ...  18.30   1  0.0    4    4
# Merc 280C            17.8  6.0  167.6  123  3.92  ...  18.90   1  0.0    4    4
# Merc 450SE           16.4  8.0  275.8  180  3.07  ...  17.40   0  0.0    3    3
# Merc 450SL           17.3  8.0  275.8  180  3.07  ...  17.60   0  0.0    3    3
# Merc 450SLC          15.2  8.0  275.8  180  3.07  ...  18.00   0  0.0    3    3
# Cadillac Fleetwood   10.4  8.0  472.0  205  2.93  ...  17.98   0  0.0    3    4
# Lincoln Continental  10.4  8.0  460.0  215  3.00  ...  17.82   0  0.0    3    4
# Chrysler Imperial    14.7  8.0  440.0  230  3.23  ...  17.42   0  0.0    3    4
# Fiat 128             32.4  4.0   78.7   66  4.08  ...  19.47   1  1.0    4    1
# Honda Civic          30.4  4.0   75.7   52  4.93  ...  18.52   1  1.0    4    2
# Toyota Corolla       33.9  4.0   71.1   65  4.22  ...  19.90   1  1.0    4    1
# Toyota Corona        21.5  4.0  120.1   97  3.70  ...  20.01   1  0.0    3    1
# Dodge Challenger     15.5  8.0  318.0  150  2.76  ...  16.87   0  0.0    3    2
# AMC Javelin          15.2  8.0  304.0  150  3.15  ...  17.30   0  0.0    3    2
# Camaro Z28           13.3  8.0  350.0  245  3.73  ...  15.41   0  0.0    3    4
# Pontiac Firebird     19.2  8.0  400.0  175  3.08  ...  17.05   0  0.0    3    2
# Fiat X1-9            27.3  4.0   79.0   66  4.08  ...  18.90   1  1.0    4    1
# Porsche 914-2        26.0  4.0  120.3   91  4.43  ...  16.70   0  1.0    5    2
# Lotus Europa         30.4  4.0   95.1  113  3.77  ...  16.90   1  1.0    5    2
# Ford Pantera L       15.8  8.0  351.0  264  4.22  ...  14.50   0  1.0    5    4
# Ferrari Dino         19.7  6.0  145.0  175  3.62  ...  15.50   0  1.0    5    6
# Maserati Bora        15.0  8.0  301.0  335  3.54  ...  14.60   0  1.0    5    8
# Volvo 142E           21.4  4.0  121.0  109  4.11  ...  18.60   1  1.0    4    2
#
# [32 rows x 11 columns]

# %% [markdown]
# If you print out your new dataset, is it clear that the variables have been converted to text values? If so, how can you tell?
#
# It should also be clear by how `plotnine` treats these variables.
#
# 1. Create side-by-side boxplots of the `mpg` variable by the different values of the `am` variable. What happens if you convert the `am` variable back to float values and then try to create this same plot? Explain the differences between the two plots.
#
# 2. Create overlaid histograms of the `hp` variable for the different values of the `cyl` variable. What happens if you convert the `cyl` variable back to float values and then try to create this same plot? Explain the differences between the two plots.

# %%
# Create plot for (1) here
from plotnine import ggplot, aes, geom_boxplot

(ggplot(df, aes(x = "am", y = "mpg", fill = "am"))
+ geom_boxplot())

# %%
#am box plot with float variables 
df["am"] = df["am"].astype(float)

(ggplot(df, aes(x = "am", y = "mpg", fill = "am"))
+ geom_boxplot())
#produces a single boxplot taking am values as continuous, not representative of true values

# %%
# Create plot for (2) here
from plotnine import geom_histogram 
(ggplot(df,
aes(
    x = "hp",
    fill = "cyl"
))
+ geom_histogram()
)
# Out:
# C:\Users\owenk\anaconda3\Lib\site-packages\plotnine\stats\stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 6'. Pick better value with 'binwidth'.

# %%
#histogram cyl, hp with cyl as float values 
df["cyl"] = df["cyl"].astype(float)
from plotnine import geom_histogram 
(ggplot(df,
aes(
    x = "hp",
    fill = "cyl"
))
+ geom_histogram()
)
#when we convert hp back to floats, the overlayed histogram fails to provide insight becasue it does not differentiate cyl values, instead representing cyl as a continuous variable. However the shape of the histogram remains the same.
# Out:
# C:\Users\owenk\anaconda3\Lib\site-packages\plotnine\stats\stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 6'. Pick better value with 'binwidth'.

# %% [markdown]
# Some of these variables, like the `cyl` variable, have numeric values that actually make sense as numbers (i.e. the number of cylinders in the engine). However, it doesn't make the most sense to "do math" with this type of variable (e.g. take averages and such) because there are so few different value this can take on AND they're an explicit choice made by the car manufacturer. So, it makes more sense to treat the `cyl` variable as a categorical variable despite it having numeric values.
#
# You will need to keep these kinds of nuances about data in mind as you work with an increasing variety and richness of data, and do more complex things with them.
#
# Choose 3 new `geometries` from the [data-to-viz website](https://www.data-to-viz.com/) for graphs that you'd like to explore using the `mtcars` dataset, and then create those graphs!

# %%
# Create plot with first new geometry here
df["cyl"] = df["cyl"].astype(str)
from plotnine import geom_point 

(ggplot(df, 
aes(
    x = "cyl",
    y = "hp"
))
+ geom_point()
)

# %%
# Create plot with second new geometry here
import seaborn as sns 
import matplotlib.pyplot as plt

sns.violinplot(x = df["cyl"], y = df["hp"])

plt.show()

# %%
# Create plot with third new geometry here
# %pip install joypy
import joypy
joypy.joyplot(
    data = df,
    by = "cyl",
    column = "hp",
    ylim = 'own', 
    figsize=(10,6)
)

plt.show()
# Out:
# Collecting joypy
#   Downloading joypy-0.2.6-py2.py3-none-any.whl.metadata (812 bytes)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\owenk\anaconda3\lib\site-packages (from joypy) (1.26.4)
# Requirement already satisfied: scipy>=0.11.0 in c:\users\owenk\anaconda3\lib\site-packages (from joypy) (1.13.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\owenk\anaconda3\lib\site-packages (from joypy) (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\owenk\anaconda3\lib\site-packages (from joypy) (3.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\owenk\anaconda3\lib\site-packages (from pandas>=0.20.0->joypy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\owenk\anaconda3\lib\site-packages (from pandas>=0.20.0->joypy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\owenk\anaconda3\lib\site-packages (from pandas>=0.20.0->joypy) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\owenk\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->joypy) (1.16.0)
# Downloading joypy-0.2.6-py2.py3-none-any.whl (8.6 kB)
# Installing collected packages: joypy
# Successfully installed joypy-0.2.6
# Note: you may need to restart the kernel to use updated packages.
# Collecting joypy
#   Downloading joypy-0.2.6-py2.py3-none-any.whl.metadata (812 bytes)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\owenk\anaconda3\lib\site-packages (from joypy) (1.26.4)
# Requirement already satisfied: scipy>=0.11.0 in c:\users\owenk\anaconda3\lib\site-packages (from joypy) (1.13.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\owenk\anaconda3\lib\site-packages (from joypy) (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\owenk\anaconda3\lib\site-packages (from joypy) (3.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\owenk\anaconda3\lib\site-packages (from pandas>=0.20.0->joypy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\owenk\anaconda3\lib\site-packages (from pandas>=0.20.0->joypy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\owenk\anaconda3\lib\site-packages (from pandas>=0.20.0->joypy) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\owenk\anaconda3\lib\site-packages (from matplotlib->joypy) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\owenk\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->joypy) (1.16.0)
# Downloading joypy-0.2.6-py2.py3-none-any.whl (8.6 kB)
# Installing collected packages: joypy
# Successfully installed joypy-0.2.6
# Note: you may need to restart the kernel to use updated packages.
